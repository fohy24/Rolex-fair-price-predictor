# %% [markdown]
# # Rolex Listing Price Prediction based on model and complications

# %%
import pandas as pd
import numpy as np
import glob
import janitor
import altair as alt
alt.data_transformers.enable("vegafusion")
# Out:
# DataTransformerRegistry.enable('vegafusion')

# %% [markdown]
# ## Data Cleaning

# %%
files = glob.glob('data/result_df/*.csv')
dirty_df = pd.concat((pd.read_csv(file, index_col=0)
                for file in files)
              )

dirty_df = dirty_df.clean_names()
dirty_df.drop_duplicates(subset=['listing_code', 'reference_number'], inplace=True)
dirty_df.dropna(subset=['brand', 'model', 'listing_code', 'price', 'title', 'subtitle', 'case_diameter'], inplace=True)
dirty_df.reset_index(drop=True, inplace=True)


dirty_df.head()
# Out:
#   listing_code  brand          model  \
# 0       IJD7R3  Rolex    Datejust 41
# 1       HOAOQ5  Rolex    Datejust 31
# 2       IJ9RY8  Rolex    Datejust 36
# 3       FDHJM3  Rolex  GMT-Master II
# 4       FFF9D3  Rolex       Explorer
#
#                                 reference_number   movement case_material  \
# 0  126331 NEW UNWORN 2023 Wimbledon 41mm Jubilee  Automatic    Gold/Steel
# 1                                         278271  Automatic    Gold/Steel
# 2                                         126231  Automatic    Gold/Steel
# 3                                     126710BLNR  Automatic         Steel
# 4                                         124270  Automatic         Steel
#
#   bracelet_material year_of_production  \
# 0        Gold/Steel               2023
# 1        Gold/Steel               2023
# 2        Gold/Steel               2023
# 3             Steel               2023
# 4             Steel               2021
#
#                                            condition  \
# 0        New\n(Brand new, without any signs of wear)
# 1        New\n(Brand new, without any signs of wear)
# 2        New\n(Brand new, without any signs of wear)
# 3        New\n(Brand new, without any signs of wear)
# 4  Very good\n(Worn with little to no signs of wear)
#
#                scope_of_delivery  ... thickness lug_width buckle_width  \
# 0  Original box, original papers  ...       NaN       NaN          NaN
# 1  Original box, original papers  ...       NaN       NaN          NaN
# 2  Original box, original papers  ...       NaN       NaN          NaN
# 3  Original box, original papers  ...       NaN       NaN          NaN
# 4  Original box, original papers  ...       NaN       NaN          NaN
#
#   frequency bracelet_thickness submariner_kermit_ref_ day_date_ref_  \
# 0       NaN                NaN                    NaN           NaN
# 1       NaN                NaN                    NaN           NaN
# 2       NaN                NaN                    NaN           NaN
# 3       NaN                NaN                    NaN           NaN
# 4       NaN                NaN                    NaN           NaN
#
#    datejust_reference_number submariner_date_reference reference
# 0                        NaN                       NaN       NaN
# 1                        NaN                       NaN       NaN
# 2                        NaN                       NaN       NaN
# 3                        NaN                       NaN       NaN
# 4                        NaN                       NaN       NaN
#
# [5 rows x 48 columns]

# %%
# clean case_diameter
def is_convertible_to_int(value):
    try:
        int(value)
        return True
    except ValueError:
        return False

convertible_mask = dirty_df['case_diameter'].str[:2].apply(is_convertible_to_int)

dirty_df = dirty_df[convertible_mask]

dirty_df['case_diameter'] = dirty_df['case_diameter'].str[:2].astype('int')

# %%
# add column of whether the price is negotiable
dirty_df.insert(loc=13, column='is_negotiable', value=dirty_df['price'].str.contains('Negotiable', case=False).astype(int))

# %%
# keep only CA$ in the `price` column
dirty_df['price'] = dirty_df['price'].str.extract('C\$([0-9,]+)')[0].str.replace(',', '')
dirty_df['price'] = pd.to_numeric(dirty_df['price'], errors='coerce')
dirty_df['price'].fillna(0, inplace=True)
dirty_df['price'] = dirty_df['price'].astype(int)

dirty_df = dirty_df.query('price != 0')
# Out:
# <>:2: DeprecationWarning: invalid escape sequence '\$'
# <>:2: DeprecationWarning: invalid escape sequence '\$'
# C:\Users\fohy2\AppData\Local\Temp\ipykernel_14912\1010010397.py:2: DeprecationWarning: invalid escape sequence '\$'
#   dirty_df['price'] = dirty_df['price'].str.extract('C\$([0-9,]+)')[0].str.replace(',', '')

# %%
# add column of whether the year of production is approximated
dirty_df.insert(loc=8, column='year_is_approximated', value=dirty_df['year_of_production'].str.contains('Approximation', case=False).astype(int))

# Clean year of production
dirty_df['year_of_production'] = dirty_df['year_of_production'].apply(lambda x: x[:4] if x != 'Unknown' else x)

# %%
# simplify the location to country only
dirty_df['country'] = dirty_df['location'].str.split(',').str[0]

# %% [markdown]
# Save the cleaned data locally

# %%
rolex_df = dirty_df
rolex_df.to_csv('data/rolex_df.csv')

# %% [markdown]
# ## EDA

# %%
display(rolex_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62495 entries, 0 to 66279
# Data columns (total 50 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   listing_code                          62495 non-null  object
#  1   brand                                 62495 non-null  object
#  2   model                                 62495 non-null  object
#  3   reference_number                      61846 non-null  object
#  4   movement                              61443 non-null  object
#  5   case_material                         60862 non-null  object
#  6   bracelet_material                     56783 non-null  object
#  7   year_of_production                    62495 non-null  object
#  8   year_is_approximated                  62495 non-null  int32
#  9   condition                             61537 non-null  object
#  10  scope_of_delivery                     62495 non-null  object
#  11  gender                                55576 non-null  object
#  12  location                              62495 non-null  object
#  13  price                                 62495 non-null  int32
#  14  availability                          62495 non-null  object
#  15  caliber_movement                      41482 non-null  object
#  16  base_caliber                          23925 non-null  object
#  17  power_reserve                         37823 non-null  object
#  18  number_of_jewels                      37490 non-null  float64
#  19  case_diameter                         62495 non-null  int32
#  20  water_resistance                      45808 non-null  object
#  21  bezel_material                        46054 non-null  object
#  22  crystal                               50999 non-null  object
#  23  dial                                  57611 non-null  object
#  24  dial_numerals                         37784 non-null  object
#  25  bracelet_color                        48105 non-null  object
#  26  clasp                                 45501 non-null  object
#  27  clasp_material                        39953 non-null  object
#  28  functions                             40925 non-null  object
#  29  title                                 62495 non-null  object
#  30  subtitle                              62495 non-null  object
#  31  rating                                56618 non-null  float64
#  32  reviews                               62495 non-null  int64
#  33  description                           55560 non-null  object
#  34  dealer_product_code                   32760 non-null  object
#  35  bracelet_length                       4514 non-null   object
#  36  alternative_reference_numbers         0 non-null      object
#  37  rolex_lady_datejust_reference_number  0 non-null      object
#  38  model_reference_number                0 non-null      object
#  39  thickness                             5957 non-null   object
#  40  lug_width                             3114 non-null   object
#  41  buckle_width                          582 non-null    object
#  42  frequency                             1452 non-null   object
#  43  bracelet_thickness                    301 non-null    object
#  44  submariner_kermit_ref_                0 non-null      object
#  45  day_date_ref_                         0 non-null      object
#  46  datejust_reference_number             0 non-null      object
#  47  submariner_date_reference             0 non-null      object
#  48  reference                             0 non-null      object
#  49  country                               62495 non-null  object
# dtypes: float64(2), int32(3), int64(1), object(44)
# memory usage: 23.6+ MB
# None

# %%
display(rolex_df.describe())
# Out:
#        year_is_approximated         price  number_of_jewels  case_diameter  \
# count          62495.000000  6.249500e+04      37490.000000   62495.000000
# mean               0.121082  3.165010e+04         31.901707      37.127162
# std                0.326225  4.314727e+04          5.082348       4.744927
# min                0.000000  8.800000e+01          2.000000       6.000000
# 25%                0.000000  1.312700e+04         31.000000      36.000000
# 50%                0.000000  2.072400e+04         31.000000      40.000000
# 75%                0.000000  3.371300e+04         31.000000      40.000000
# max                1.000000  1.506426e+06        200.000000      90.000000
#
#              rating       reviews
# count  56618.000000  62495.000000
# mean       4.741688    613.956285
# std        0.291935   1363.128526
# min        1.000000      0.000000
# 25%        4.700000     44.000000
# 50%        4.800000    208.000000
# 75%        4.900000    585.000000
# max        5.000000   8637.000000

# %% [markdown]
# We will use only the following columns since they have fewer missing values and have more variation even for the same model. Features that are unrelated to the watch model is especially interesting, such as `condition` and `scope_of_delivery`, as they provide insights on how these factor in to the listing price.

# %%
df = rolex_df[['model', 'movement', 'case_material', 'bracelet_material',
               'year_of_production', 'condition', 'scope_of_delivery',
               'country', 'availability', 'case_diameter', 'bezel_material',
               'crystal', 'dial', 'bracelet_color', 'clasp', 'clasp_material',
               'rating', 'reviews']]
df.head(1)
# Out:
#          model   movement case_material bracelet_material year_of_production  \
# 0  Datejust 41  Automatic    Gold/Steel        Gold/Steel               2023
#
#                                      condition              scope_of_delivery  \
# 0  New\n(Brand new, without any signs of wear)  Original box, original papers
#
#                     country      availability  case_diameter bezel_material  \
# 0  United States of America  Item is in stock             41      Rose gold
#
#             crystal    dial bracelet_color       clasp clasp_material  rating  \
# 0  Sapphire crystal  Silver     Gold/Steel  Fold clasp     Gold/Steel     4.2
#
#    reviews
# 0       11

# %%
df.shape
# Out:
# (62495, 18)

# %%
# alt.Chart(df).mark_bar().encode(
#      alt.X(alt.repeat()).type('quantitative').bin(maxbins=40),
#      y='count()',
# ).properties(
#     width=300,
#     height=200
# ).repeat(
#     ['model', 'movement']
# )

alt.Chart(df).mark_bar().encode(
    y=alt.Y('model:N', sort='-x'),
    x=alt.X('count():Q', title='Count')
)
# Out:
# alt.Chart(...)

# %%
plot_columns = df.columns.to_list()

for column in plot_columns:
    top_categories = df[column].value_counts().head(10).index
    filtered_df = df[df[column].isin(top_categories)]

    chart = alt.Chart(filtered_df).mark_bar().encode(
        y=alt.Y(f"{column}:N", sort='-x'),
        x=alt.X('count()', title='Count')
    ).properties(
        title=f"Top 10 Categories in {column}"
    )
    
    chart.display()
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
