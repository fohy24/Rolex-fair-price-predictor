# %%
import pandas as pd
import numpy as np
import glob
import janitor
import altair as alt
import matplotlib as plt
alt.data_transformers.enable("vegafusion")
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split

# %%
rolex_df = pd.read_csv('data/rolex_df.csv')

# %%
display(rolex_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62495 entries, 0 to 62494
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 62495 non-null  object
#  1   movement              61443 non-null  object
#  2   case_material         60862 non-null  object
#  3   bracelet_material     56783 non-null  object
#  4   year_of_production    46712 non-null  float64
#  5   year_is_approximated  62495 non-null  int64
#  6   condition             61537 non-null  object
#  7   scope_of_delivery     62495 non-null  object
#  8   country               62495 non-null  object
#  9   availability          62495 non-null  object
#  10  case_diameter         62495 non-null  int64
#  11  bezel_material        46054 non-null  object
#  12  crystal               50999 non-null  object
#  13  dial                  57611 non-null  object
#  14  bracelet_color        48105 non-null  object
#  15  clasp                 45501 non-null  object
#  16  clasp_material        39953 non-null  object
#  17  rating                56618 non-null  float64
#  18  reviews               62495 non-null  int64
#  19  price                 62495 non-null  int64
#  20  is_negotiable         62495 non-null  int64
# dtypes: float64(2), int64(5), object(14)
# memory usage: 10.0+ MB
# None

# %% [markdown]
# We will use only the following columns since they have fewer missing values and have more variation even for the same model. Features that are unrelated to the watch model is especially interesting, such as `condition` and `scope_of_delivery`, as they provide insights on how these factor in to the listing price.

# %%
rolex_df = rolex_df[['model', 'movement', 'case_material', 'bracelet_material',
               'year_of_production', 'year_is_approximated', 'condition', 'scope_of_delivery',
               'country', 'availability', 'case_diameter', 'bezel_material',
               'crystal', 'dial', 'bracelet_color', 'clasp', 'clasp_material',
               'rating', 'reviews', 'price', 'is_negotiable']]
print(rolex_df.shape)
rolex_df.head()
# Out:
# (62495, 21)
#            model   movement case_material bracelet_material  \
# 0    Datejust 41  Automatic    Gold/Steel        Gold/Steel
# 1    Datejust 31  Automatic    Gold/Steel        Gold/Steel
# 2    Datejust 36  Automatic    Gold/Steel        Gold/Steel
# 3  GMT-Master II  Automatic         Steel             Steel
# 4       Explorer  Automatic         Steel             Steel
#
#    year_of_production  year_is_approximated  \
# 0              2023.0                     0
# 1              2023.0                     0
# 2              2023.0                     0
# 3              2023.0                     0
# 4              2021.0                     0
#
#                                            condition  \
# 0        New\n(Brand new, without any signs of wear)
# 1        New\n(Brand new, without any signs of wear)
# 2        New\n(Brand new, without any signs of wear)
# 3        New\n(Brand new, without any signs of wear)
# 4  Very good\n(Worn with little to no signs of wear)
#
#                scope_of_delivery                   country      availability  \
# 0  Original box, original papers  United States of America  Item is in stock
# 1  Original box, original papers  United States of America  Item is in stock
# 2  Original box, original papers  United States of America  Item is in stock
# 3  Original box, original papers  United States of America  Item is in stock
# 4  Original box, original papers  United States of America  Item is in stock
#
#    ...  bezel_material           crystal             dial bracelet_color  \
# 0  ...       Rose gold  Sapphire crystal           Silver     Gold/Steel
# 1  ...       Rose gold  Sapphire crystal  Mother of pearl     Gold/Steel
# 2  ...       Rose gold  Sapphire crystal             Grey     Gold/Steel
# 3  ...         Ceramic  Sapphire crystal            Black          Steel
# 4  ...           Steel  Sapphire crystal            Black          Steel
#
#         clasp clasp_material rating  reviews  price  is_negotiable
# 0  Fold clasp     Gold/Steel    4.2       11  23421              1
# 1  Fold clasp     Gold/Steel    5.0      398  25556              0
# 2  Fold clasp     Gold/Steel    5.0      398  25556              0
# 3  Fold clasp          Steel    5.0      398  25556              0
# 4  Fold clasp          Steel    4.9      797  11711              0
#
# [5 rows x 21 columns]

# %%
train_df, test_df = train_test_split(rolex_df, test_size=0.2, random_state=123)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49996, 21)
# (12499, 21)

# %%
X_train, y_train = train_df.drop(
    columns=["price"]), train_df["price"]
y_train = pd.DataFrame(y_train)
X_test, y_test = test_df.drop(
    columns=["price"]), test_df["price"]
y_test = pd.DataFrame(y_test)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (49996, 20)
# (49996, 1)
# (12499, 20)
# (12499, 1)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49996 entries, 698 to 52734
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 49996 non-null  object
#  1   movement              49159 non-null  object
#  2   case_material         48678 non-null  object
#  3   bracelet_material     45462 non-null  object
#  4   year_of_production    37355 non-null  float64
#  5   year_is_approximated  49996 non-null  int64
#  6   condition             49234 non-null  object
#  7   scope_of_delivery     49996 non-null  object
#  8   country               49996 non-null  object
#  9   availability          49996 non-null  object
#  10  case_diameter         49996 non-null  int64
#  11  bezel_material        36838 non-null  object
#  12  crystal               40790 non-null  object
#  13  dial                  46103 non-null  object
#  14  bracelet_color        38567 non-null  object
#  15  clasp                 36415 non-null  object
#  16  clasp_material        31975 non-null  object
#  17  rating                45316 non-null  float64
#  18  reviews               49996 non-null  int64
#  19  is_negotiable         49996 non-null  int64
# dtypes: float64(2), int64(4), object(14)
# memory usage: 8.0+ MB

# %%
plot_columns = X_train.columns.to_list()

for column in plot_columns:
    top_categories = X_train[column].value_counts().head(10).index
    filtered_X_train = X_train[X_train[column].isin(top_categories)]

    chart = alt.Chart(filtered_X_train).mark_bar().encode(
        y=alt.Y(f"{column}:N", sort='-x'),
        x=alt.X('count()', title='Count')
    ).properties(
        title=f"Top 10 Categories in {column}"
    )
    
    chart.display()
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
alt.Chart(y_train,
          title='Histogram of Rolex price').mark_bar().encode(
    alt.X('price:Q').bin(maxbins=40),
    y='count()'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Manual inspect if there is any outliers can be removed just by clipping the data

# %%
y_train.describe(percentiles=[.25, .5, .75, 0.975]).apply(lambda s: s.apply('{0:.0f}'.format))
# Out:
#          price
# count    49996
# mean     31724
# std      43328
# min        198
# 25%      13125
# 50%      20724
# 75%      33848
# 97.5%   119729
# max    1506426

# %%
alt.Chart(y_train.query('price <= 120000'),
          title='Histogram of Rolex price').mark_bar().encode(
    alt.X('price:Q').bin(maxbins=40),
    y='count()'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# The above histogram is showing at least 97.5% of the price data. It is difficult to interpret the distribution with the outliers so they are disregarded for the purpose of this visualization.
#
# The distribution of price resembles a Gamma distribution.

# %%
train_df.corr(numeric_only=True).round(
    decimals=3).style.background_gradient()
# Out:
# <style type="text/css">
# #T_1bc56_row0_col0, #T_1bc56_row1_col1, #T_1bc56_row2_col2, #T_1bc56_row3_col3, #T_1bc56_row4_col4, #T_1bc56_row5_col5, #T_1bc56_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1bc56_row0_col1, #T_1bc56_row1_col0, #T_1bc56_row4_col2, #T_1bc56_row4_col5, #T_1bc56_row4_col6, #T_1bc56_row5_col3, #T_1bc56_row6_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1bc56_row0_col2 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_1bc56_row0_col3, #T_1bc56_row1_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_1bc56_row0_col4 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_1bc56_row0_col5 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_1bc56_row0_col6, #T_1bc56_row3_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_1bc56_row1_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_1bc56_row1_col4 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_1bc56_row1_col5 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_1bc56_row1_col6 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_1bc56_row2_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_1bc56_row2_col1, #T_1bc56_row6_col5 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_1bc56_row2_col3, #T_1bc56_row2_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1bc56_row2_col5 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_1bc56_row2_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_1bc56_row3_col0, #T_1bc56_row3_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_1bc56_row3_col4 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_1bc56_row3_col5, #T_1bc56_row5_col4, #T_1bc56_row6_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_1bc56_row3_col6 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_1bc56_row4_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_1bc56_row4_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_1bc56_row4_col3 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_1bc56_row5_col0 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_1bc56_row5_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_1bc56_row5_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_1bc56_row5_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_1bc56_row6_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_1bc56_row6_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_1bc56_row6_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# </style>
# <table id="T_1bc56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bc56_level0_col0" class="col_heading level0 col0" >year_of_production</th>
#       <th id="T_1bc56_level0_col1" class="col_heading level0 col1" >year_is_approximated</th>
#       <th id="T_1bc56_level0_col2" class="col_heading level0 col2" >case_diameter</th>
#       <th id="T_1bc56_level0_col3" class="col_heading level0 col3" >rating</th>
#       <th id="T_1bc56_level0_col4" class="col_heading level0 col4" >reviews</th>
#       <th id="T_1bc56_level0_col5" class="col_heading level0 col5" >price</th>
#       <th id="T_1bc56_level0_col6" class="col_heading level0 col6" >is_negotiable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bc56_level0_row0" class="row_heading level0 row0" >year_of_production</th>
#       <td id="T_1bc56_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1bc56_row0_col1" class="data row0 col1" >-0.161000</td>
#       <td id="T_1bc56_row0_col2" class="data row0 col2" >0.318000</td>
#       <td id="T_1bc56_row0_col3" class="data row0 col3" >0.017000</td>
#       <td id="T_1bc56_row0_col4" class="data row0 col4" >0.009000</td>
#       <td id="T_1bc56_row0_col5" class="data row0 col5" >0.127000</td>
#       <td id="T_1bc56_row0_col6" class="data row0 col6" >-0.012000</td>
#     </tr>
#     <tr>
#       <th id="T_1bc56_level0_row1" class="row_heading level0 row1" >year_is_approximated</th>
#       <td id="T_1bc56_row1_col0" class="data row1 col0" >-0.161000</td>
#       <td id="T_1bc56_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1bc56_row1_col2" class="data row1 col2" >-0.076000</td>
#       <td id="T_1bc56_row1_col3" class="data row1 col3" >0.016000</td>
#       <td id="T_1bc56_row1_col4" class="data row1 col4" >0.262000</td>
#       <td id="T_1bc56_row1_col5" class="data row1 col5" >-0.028000</td>
#       <td id="T_1bc56_row1_col6" class="data row1 col6" >0.067000</td>
#     </tr>
#     <tr>
#       <th id="T_1bc56_level0_row2" class="row_heading level0 row2" >case_diameter</th>
#       <td id="T_1bc56_row2_col0" class="data row2 col0" >0.318000</td>
#       <td id="T_1bc56_row2_col1" class="data row2 col1" >-0.076000</td>
#       <td id="T_1bc56_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_1bc56_row2_col3" class="data row2 col3" >0.013000</td>
#       <td id="T_1bc56_row2_col4" class="data row2 col4" >-0.089000</td>
#       <td id="T_1bc56_row2_col5" class="data row2 col5" >0.224000</td>
#       <td id="T_1bc56_row2_col6" class="data row2 col6" >0.046000</td>
#     </tr>
#     <tr>
#       <th id="T_1bc56_level0_row3" class="row_heading level0 row3" >rating</th>
#       <td id="T_1bc56_row3_col0" class="data row3 col0" >0.017000</td>
#       <td id="T_1bc56_row3_col1" class="data row3 col1" >0.016000</td>
#       <td id="T_1bc56_row3_col2" class="data row3 col2" >0.013000</td>
#       <td id="T_1bc56_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_1bc56_row3_col4" class="data row3 col4" >0.099000</td>
#       <td id="T_1bc56_row3_col5" class="data row3 col5" >-0.008000</td>
#       <td id="T_1bc56_row3_col6" class="data row3 col6" >0.041000</td>
#     </tr>
#     <tr>
#       <th id="T_1bc56_level0_row4" class="row_heading level0 row4" >reviews</th>
#       <td id="T_1bc56_row4_col0" class="data row4 col0" >0.009000</td>
#       <td id="T_1bc56_row4_col1" class="data row4 col1" >0.262000</td>
#       <td id="T_1bc56_row4_col2" class="data row4 col2" >-0.089000</td>
#       <td id="T_1bc56_row4_col3" class="data row4 col3" >0.099000</td>
#       <td id="T_1bc56_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_1bc56_row4_col5" class="data row4 col5" >-0.059000</td>
#       <td id="T_1bc56_row4_col6" class="data row4 col6" >-0.115000</td>
#     </tr>
#     <tr>
#       <th id="T_1bc56_level0_row5" class="row_heading level0 row5" >price</th>
#       <td id="T_1bc56_row5_col0" class="data row5 col0" >0.127000</td>
#       <td id="T_1bc56_row5_col1" class="data row5 col1" >-0.028000</td>
#       <td id="T_1bc56_row5_col2" class="data row5 col2" >0.224000</td>
#       <td id="T_1bc56_row5_col3" class="data row5 col3" >-0.008000</td>
#       <td id="T_1bc56_row5_col4" class="data row5 col4" >-0.059000</td>
#       <td id="T_1bc56_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_1bc56_row5_col6" class="data row5 col6" >0.019000</td>
#     </tr>
#     <tr>
#       <th id="T_1bc56_level0_row6" class="row_heading level0 row6" >is_negotiable</th>
#       <td id="T_1bc56_row6_col0" class="data row6 col0" >-0.012000</td>
#       <td id="T_1bc56_row6_col1" class="data row6 col1" >0.067000</td>
#       <td id="T_1bc56_row6_col2" class="data row6 col2" >0.046000</td>
#       <td id="T_1bc56_row6_col3" class="data row6 col3" >0.041000</td>
#       <td id="T_1bc56_row6_col4" class="data row6 col4" >-0.115000</td>
#       <td id="T_1bc56_row6_col5" class="data row6 col5" >0.019000</td>
#       <td id="T_1bc56_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The price seems to be slightly positively correlated with case diameter, which is expected as larger models are usually equipped with more complications that drive up the price.
