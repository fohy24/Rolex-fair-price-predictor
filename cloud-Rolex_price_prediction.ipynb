# %% [markdown]
# # Rolex Listing Price Prediction based on model and complications

# %%
import pandas as pd
import numpy as np
import glob
import janitor
import altair as alt
import matplotlib as plt
alt.data_transformers.enable("vegafusion")
# Out:
# DataTransformerRegistry.enable('vegafusion')

# %%
import warnings

# Specifically suppress the UserWarnings related to unknown categories in OneHotEncoder
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Cleaning

# %%
files = glob.glob('data/result_df/*.csv')
dirty_df = pd.concat((pd.read_csv(file, index_col=0)
                for file in files)
              )

dirty_df = dirty_df.clean_names()
dirty_df.drop_duplicates(subset=['listing_code', 'reference_number'], inplace=True)
dirty_df.dropna(subset=['brand', 'model', 'listing_code', 'price', 'title', 'subtitle', 'case_diameter'], inplace=True)
dirty_df.reset_index(drop=True, inplace=True)


dirty_df.head()
# Out:
#   listing_code  brand             model reference_number   movement  \
# 0       JB6751  Rolex       Datejust 36           126234     Quartz
# 1       IK45G9  Rolex       Day-Date 36           18239A  Automatic
# 2       IW74W1  Rolex           Daytona           16523G  Automatic
# 3       JPV699  Rolex   Submariner Date         116610LV  Automatic
# 4       JG57B0  Rolex  Sea-Dweller 4000            16600  Automatic
#
#   case_material bracelet_material year_of_production  \
# 0    Gold/Steel             Steel               2023
# 1    White gold        White gold            Unknown
# 2         Steel             Steel            Unknown
# 3         Steel             Steel            Unknown
# 4         Steel             Steel               1993
#
#                                            condition  \
# 0    Unworn\n(Mint condition, without signs of wear)
# 1  Very good\n(Worn with little to no signs of wear)
# 2  Very good\n(Worn with little to no signs of wear)
# 3  Very good\n(Worn with little to no signs of wear)
# 4  Very good\n(Worn with little to no signs of wear)
#
#                   scope_of_delivery  ... frequency buckle_width  \
# 0     Original box, original papers  ...       NaN          NaN
# 1  Original papers, no original box  ...       NaN          NaN
# 2  Original papers, no original box  ...       NaN          NaN
# 3     Original box, original papers  ...       NaN          NaN
# 4     Original box, original papers  ...       NaN          NaN
#
#   bracelet_thickness model_reference_number day_date_ref_  \
# 0                NaN                    NaN           NaN
# 1                NaN                    NaN           NaN
# 2                NaN                    NaN           NaN
# 3                NaN                    NaN           NaN
# 4                NaN                    NaN           NaN
#
#   datejust_reference_number rolex_lady_datejust_reference_number  \
# 0                       NaN                                  NaN
# 1                       NaN                                  NaN
# 2                       NaN                                  NaN
# 3                       NaN                                  NaN
# 4                       NaN                                  NaN
#
#    submariner_kermit_ref_ reference submariner_date_reference
# 0                     NaN       NaN                       NaN
# 1                     NaN       NaN                       NaN
# 2                     NaN       NaN                       NaN
# 3                     NaN       NaN                       NaN
# 4                     NaN       NaN                       NaN
#
# [5 rows x 48 columns]

# %%
# clean case_diameter
def is_convertible_to_int(value):
    try:
        int(value)
        return True
    except ValueError:
        return False

convertible_mask = dirty_df['case_diameter'].str[:2].apply(is_convertible_to_int)

dirty_df = dirty_df[convertible_mask]

dirty_df['case_diameter'] = dirty_df['case_diameter'].str[:2].astype('int')

# %%
# add column of whether the price is negotiable
dirty_df.insert(loc=13, column='is_negotiable', value=dirty_df['price'].str.contains('Negotiable', case=False).astype(int))

# %%
# keep only CA$ in the `price` column
dirty_df['price'] = dirty_df['price'].str.extract('C\$([0-9,]+)')[0].str.replace(',', '')
dirty_df['price'] = pd.to_numeric(dirty_df['price'], errors='coerce')
dirty_df['price'].fillna(0, inplace=True)
dirty_df['price'] = dirty_df['price'].astype(int)

dirty_df = dirty_df.query('price != 0')

# %%
# add column of whether the year of production is approximated
dirty_df.insert(loc=8, column='year_is_approximated', value=dirty_df['year_of_production'].str.contains('Approximation', case=False).astype(int))

# Clean year of production
dirty_df['year_of_production'] = dirty_df['year_of_production'].apply(lambda x: x[:4] if x != 'Unknown' else x)

# %%
# simplify the location to country only
dirty_df['country'] = dirty_df['location'].str.split(',').str[0]

# %% [markdown]
# Save the cleaned data locally

# %%
rolex_df = dirty_df
rolex_df.to_csv('data/rolex_df.csv')

# %% [markdown]
# ## EDA

# %%
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split

# %%
display(rolex_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62495 entries, 0 to 66279
# Data columns (total 51 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   listing_code                          62495 non-null  object
#  1   brand                                 62495 non-null  object
#  2   model                                 62495 non-null  object
#  3   reference_number                      61846 non-null  object
#  4   movement                              61443 non-null  object
#  5   case_material                         60862 non-null  object
#  6   bracelet_material                     56783 non-null  object
#  7   year_of_production                    62495 non-null  object
#  8   year_is_approximated                  62495 non-null  int64
#  9   condition                             61537 non-null  object
#  10  scope_of_delivery                     62495 non-null  object
#  11  gender                                55576 non-null  object
#  12  location                              62495 non-null  object
#  13  price                                 62495 non-null  int64
#  14  is_negotiable                         62495 non-null  int64
#  15  availability                          62495 non-null  object
#  16  caliber_movement                      41482 non-null  object
#  17  base_caliber                          23925 non-null  object
#  18  power_reserve                         37823 non-null  object
#  19  number_of_jewels                      37490 non-null  float64
#  20  case_diameter                         62495 non-null  int64
#  21  water_resistance                      45808 non-null  object
#  22  bezel_material                        46054 non-null  object
#  23  crystal                               50999 non-null  object
#  24  dial                                  57611 non-null  object
#  25  dial_numerals                         37784 non-null  object
#  26  bracelet_color                        48105 non-null  object
#  27  clasp                                 45501 non-null  object
#  28  clasp_material                        39953 non-null  object
#  29  functions                             40925 non-null  object
#  30  title                                 62495 non-null  object
#  31  subtitle                              62495 non-null  object
#  32  rating                                56618 non-null  float64
#  33  reviews                               62495 non-null  int64
#  34  description                           55560 non-null  object
#  35  dealer_product_code                   32760 non-null  object
#  36  thickness                             5957 non-null   object
#  37  bracelet_length                       4514 non-null   object
#  38  alternative_reference_numbers         0 non-null      object
#  39  lug_width                             3114 non-null   object
#  40  frequency                             1452 non-null   object
#  41  buckle_width                          582 non-null    object
#  42  bracelet_thickness                    301 non-null    object
#  43  model_reference_number                0 non-null      object
#  44  day_date_ref_                         0 non-null      object
#  45  datejust_reference_number             0 non-null      object
#  46  rolex_lady_datejust_reference_number  0 non-null      object
#  47  submariner_kermit_ref_                0 non-null      object
#  48  reference                             0 non-null      object
#  49  submariner_date_reference             0 non-null      object
#  50  country                               62495 non-null  object
# dtypes: float64(2), int64(5), object(44)
# memory usage: 24.8+ MB
# None

# %%
df = rolex_df[['model', 'movement', 'case_material', 'bracelet_material',
               'year_of_production', 'year_is_approximated', 'condition', 'scope_of_delivery',
               'country', 'availability', 'case_diameter', 'bezel_material',
               'crystal', 'dial', 'bracelet_color', 'clasp', 'clasp_material',
               'rating', 'reviews', 'price', 'is_negotiable']]
df.head(1)
# Out:
#          model movement case_material bracelet_material year_of_production  \
# 0  Datejust 36   Quartz    Gold/Steel             Steel               2023
#
#    year_is_approximated                                        condition  \
# 0                     0  Unworn\n(Mint condition, without signs of wear)
#
#                scope_of_delivery   country      availability  ...  \
# 0  Original box, original papers  Malaysia  Item is in stock  ...
#
#    bezel_material           crystal  dial bracelet_color       clasp  \
# 0      White gold  Sapphire crystal  Grey          Steel  Fold clasp
#
#   clasp_material rating  reviews  price  is_negotiable
# 0          Steel    NaN        0  14959              1
#
# [1 rows x 21 columns]

# %%
df.shape
# Out:
# (62495, 21)

# %% [markdown]
# We will use only the following columns since they have fewer missing values and have more variation even for the same model. Features that are unrelated to the watch model is especially interesting, such as `condition` and `scope_of_delivery`, as they provide insights on how these factor in to the listing price.

# %%
train_df, test_df = train_test_split(df, test_size=0.3, random_state=123)
print(train_df.shape)
print(test_df.shape)
# Out:
# (43746, 21)
# (18749, 21)

# %%
X_train, y_train = train_df.drop(
    columns=["price"]), train_df["price"]
y_train = pd.DataFrame(y_train)
X_test, y_test = test_df.drop(
    columns=["price"]), test_df["price"]
y_test = pd.DataFrame(y_test)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (43746, 20)
# (43746, 1)
# (18749, 20)
# (18749, 1)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43746 entries, 63223 to 56395
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 43746 non-null  object
#  1   movement              43024 non-null  object
#  2   case_material         42591 non-null  object
#  3   bracelet_material     39779 non-null  object
#  4   year_of_production    43746 non-null  object
#  5   year_is_approximated  43746 non-null  int64
#  6   condition             43081 non-null  object
#  7   scope_of_delivery     43746 non-null  object
#  8   country               43746 non-null  object
#  9   availability          43746 non-null  object
#  10  case_diameter         43746 non-null  int64
#  11  bezel_material        32242 non-null  object
#  12  crystal               35680 non-null  object
#  13  dial                  40358 non-null  object
#  14  bracelet_color        33701 non-null  object
#  15  clasp                 31859 non-null  object
#  16  clasp_material        28019 non-null  object
#  17  rating                39642 non-null  float64
#  18  reviews               43746 non-null  int64
#  19  is_negotiable         43746 non-null  int64
# dtypes: float64(1), int64(4), object(15)
# memory usage: 7.0+ MB

# %%
plot_columns = X_train.columns.to_list()

for column in plot_columns:
    top_categories = X_train[column].value_counts().head(10).index
    filtered_X_train = X_train[X_train[column].isin(top_categories)]

    chart = alt.Chart(filtered_X_train).mark_bar().encode(
        y=alt.Y(f"{column}:N", sort='-x'),
        x=alt.X('count()', title='Count')
    ).properties(
        title=f"Top 10 Categories in {column}"
    )
    
    chart.display()
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
y_train.describe(percentiles=[.25, .5, .75, 0.975]).apply(lambda s: s.apply('{0:.0f}'.format))
# Out:
#          price
# count    43746
# mean     31600
# std      42708
# min         88
# 25%      13125
# 50%      20709
# 75%      33713
# 97.5%   118300
# max    1506426

# %%
alt.Chart(y_train.query('price <= 120000'),
          title='Histogram of Rolex price').mark_bar().encode(
    alt.X('price:Q').bin(maxbins=40),
    y='count()'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# The above histogram is showing at least 97.5% of the price data. It is difficult to interpret the distribution with the outliers so they are disregarded for the purpose of this visualization.

# %%
train_df.corr(numeric_only=True).round(
    decimals=3).style.background_gradient()
# Out:
# <style type="text/css">
# #T_887ee_row0_col0, #T_887ee_row1_col1, #T_887ee_row2_col2, #T_887ee_row3_col3, #T_887ee_row4_col4, #T_887ee_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_887ee_row0_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_887ee_row0_col2, #T_887ee_row1_col2, #T_887ee_row1_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_887ee_row0_col3 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_887ee_row0_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_887ee_row0_col5 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_887ee_row1_col0, #T_887ee_row3_col1, #T_887ee_row3_col4, #T_887ee_row3_col5, #T_887ee_row4_col2, #T_887ee_row5_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_887ee_row1_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_887ee_row1_col5 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_887ee_row2_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_887ee_row2_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_887ee_row2_col3 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_887ee_row2_col4, #T_887ee_row4_col3, #T_887ee_row5_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_887ee_row2_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_887ee_row3_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_887ee_row3_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_887ee_row4_col0 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_887ee_row4_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_887ee_row4_col5, #T_887ee_row5_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_887ee_row5_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_887ee_row5_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# </style>
# <table id="T_887ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_887ee_level0_col0" class="col_heading level0 col0" >year_is_approximated</th>
#       <th id="T_887ee_level0_col1" class="col_heading level0 col1" >case_diameter</th>
#       <th id="T_887ee_level0_col2" class="col_heading level0 col2" >rating</th>
#       <th id="T_887ee_level0_col3" class="col_heading level0 col3" >reviews</th>
#       <th id="T_887ee_level0_col4" class="col_heading level0 col4" >price</th>
#       <th id="T_887ee_level0_col5" class="col_heading level0 col5" >is_negotiable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_887ee_level0_row0" class="row_heading level0 row0" >year_is_approximated</th>
#       <td id="T_887ee_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_887ee_row0_col1" class="data row0 col1" >-0.074000</td>
#       <td id="T_887ee_row0_col2" class="data row0 col2" >0.013000</td>
#       <td id="T_887ee_row0_col3" class="data row0 col3" >0.260000</td>
#       <td id="T_887ee_row0_col4" class="data row0 col4" >-0.028000</td>
#       <td id="T_887ee_row0_col5" class="data row0 col5" >0.071000</td>
#     </tr>
#     <tr>
#       <th id="T_887ee_level0_row1" class="row_heading level0 row1" >case_diameter</th>
#       <td id="T_887ee_row1_col0" class="data row1 col0" >-0.074000</td>
#       <td id="T_887ee_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_887ee_row1_col2" class="data row1 col2" >0.015000</td>
#       <td id="T_887ee_row1_col3" class="data row1 col3" >-0.089000</td>
#       <td id="T_887ee_row1_col4" class="data row1 col4" >0.226000</td>
#       <td id="T_887ee_row1_col5" class="data row1 col5" >0.049000</td>
#     </tr>
#     <tr>
#       <th id="T_887ee_level0_row2" class="row_heading level0 row2" >rating</th>
#       <td id="T_887ee_row2_col0" class="data row2 col0" >0.013000</td>
#       <td id="T_887ee_row2_col1" class="data row2 col1" >0.015000</td>
#       <td id="T_887ee_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_887ee_row2_col3" class="data row2 col3" >0.099000</td>
#       <td id="T_887ee_row2_col4" class="data row2 col4" >-0.012000</td>
#       <td id="T_887ee_row2_col5" class="data row2 col5" >0.037000</td>
#     </tr>
#     <tr>
#       <th id="T_887ee_level0_row3" class="row_heading level0 row3" >reviews</th>
#       <td id="T_887ee_row3_col0" class="data row3 col0" >0.260000</td>
#       <td id="T_887ee_row3_col1" class="data row3 col1" >-0.089000</td>
#       <td id="T_887ee_row3_col2" class="data row3 col2" >0.099000</td>
#       <td id="T_887ee_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_887ee_row3_col4" class="data row3 col4" >-0.065000</td>
#       <td id="T_887ee_row3_col5" class="data row3 col5" >-0.118000</td>
#     </tr>
#     <tr>
#       <th id="T_887ee_level0_row4" class="row_heading level0 row4" >price</th>
#       <td id="T_887ee_row4_col0" class="data row4 col0" >-0.028000</td>
#       <td id="T_887ee_row4_col1" class="data row4 col1" >0.226000</td>
#       <td id="T_887ee_row4_col2" class="data row4 col2" >-0.012000</td>
#       <td id="T_887ee_row4_col3" class="data row4 col3" >-0.065000</td>
#       <td id="T_887ee_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_887ee_row4_col5" class="data row4 col5" >0.023000</td>
#     </tr>
#     <tr>
#       <th id="T_887ee_level0_row5" class="row_heading level0 row5" >is_negotiable</th>
#       <td id="T_887ee_row5_col0" class="data row5 col0" >0.071000</td>
#       <td id="T_887ee_row5_col1" class="data row5 col1" >0.049000</td>
#       <td id="T_887ee_row5_col2" class="data row5 col2" >0.037000</td>
#       <td id="T_887ee_row5_col3" class="data row5 col3" >-0.118000</td>
#       <td id="T_887ee_row5_col4" class="data row5 col4" >0.023000</td>
#       <td id="T_887ee_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The price seems to be slightly positively correlated with case diameter, which is expected as larger models are usually equipped with more complications that drive up the price.

# %% [markdown]
# ## Models

# %% [markdown]
# ### Preprocessing

# %%
# imports
import sys, os
import time

import numpy as np
import pandas as pd
import altair as alt
from IPython.display import HTML

sys.path.append(os.path.join(os.path.abspath("."), "code"))

from IPython.display import display

# Classifiers and regressors
from sklearn.dummy import DummyClassifier, DummyRegressor

# Preprocessing and pipeline
from sklearn.impute import SimpleImputer

# train test split and cross validation
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.preprocessing import (
    MinMaxScaler,
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import *
from sklearn.tree import *
from sklearn.ensemble import *
from sklearn.svm import *
from lightgbm.sklearn import *
from sklearn.model_selection import *
from xgboost import XGBRegressor

# %%
# adapted from 571 lecture notes
# code from lecture
def mean_std_cross_val_scores(model, X_train, y_train, **kwargs):
    """
    Returns mean and std of cross validation

    Parameters
    ----------
    model :
        scikit-learn model
    X_train : numpy array or pandas DataFrame
        X in the training data
    y_train :
        y in the training data

    Returns
    ----------
        pandas Series with mean scores from cross_validation
    """

    scores = cross_validate(model, X_train, y_train, n_jobs=-1, **kwargs)

    mean_scores = pd.DataFrame(scores).mean()
    std_scores = pd.DataFrame(scores).std()
    out_col = []

    for i in range(len(mean_scores)):
        out_col.append((f"%0.3f (+/- %0.3f)" %
                       (mean_scores.iloc[i], std_scores.iloc[i])))

    return pd.Series(data=out_col, index=mean_scores.index)

# %% [markdown]
# One-hot encoding is applied on categorical features and scaling on numerical features. The preprocesspr with scaler is used only for distance-based models that are sensitive to units in features. It is easier to interpret the feature importance with unscaled data when using models that are robust to such data.

# %%
categorcial_feats = [col for col in X_train.columns if col not in ['case_diameter', 'rating', 'reviews']]
numerical_feats = ['case_diameter', 'rating', 'reviews']

categorical_pipe = make_pipeline(OneHotEncoder(drop='if_binary', handle_unknown='ignore'))
numerical_pipe = make_pipeline(StandardScaler(), SimpleImputer(strategy='median'))

preprocessor = make_column_transformer((categorical_pipe, categorcial_feats))
preprocessor_with_scaler = make_column_transformer((categorical_pipe, categorcial_feats),
                                                    (numerical_pipe, numerical_feats))
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline',
#                                  Pipeline(steps=[('onehotencoder',
#                                                   OneHotEncoder(drop='if_binary',
#                                                                 handle_unknown='ignore'))]),
#                                  ['model', 'movement', 'case_material',
#                                   'bracelet_material', 'year_of_production',
#                                   'year_is_approximated', 'condition',
#                                   'scope_of_delivery', 'country',
#                                   'availability', 'bezel_material', 'crystal',
#                                   'dial', 'bracelet_color', 'clasp',
#                                   'clasp_material', 'is_negotiable'])])

# %% [markdown]
# ### Model Fitting

# %%
# create a dictionary for storing model scores
results_dict = {}

# %% [markdown]
# #### Baseline - Simple Linear Regression

# %%
import os
os.cpu_count()

import multiprocessing
multiprocessing.cpu_count()
# Out:
# 32

# %%
linear_reg = make_pipeline(preprocessor,
                           LinearRegression(n_jobs=3))
results_dict["linear regression"] = mean_std_cross_val_scores(
    linear_reg, X_train, y_train, return_train_score=True
)
pd.DataFrame(results_dict).T
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             fit_time         score_time         test_score  \
# linear regression  1.244 (+/- 0.049)  0.087 (+/- 0.004)  0.440 (+/- 0.022)
#
#                          train_score
# linear regression  0.457 (+/- 0.005)

# %% [markdown]
# #### Classical Linear Regression Models: Ridge and Lasso

# %%
ridge = make_pipeline(preprocessor,
                      Ridge())
results_dict["ridge"] = mean_std_cross_val_scores(
    ridge, X_train, y_train, return_train_score=True
)
pd.DataFrame(results_dict).T
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             fit_time         score_time         test_score  \
# linear regression  1.244 (+/- 0.049)  0.087 (+/- 0.004)  0.440 (+/- 0.022)
# ridge              0.790 (+/- 0.013)  0.085 (+/- 0.006)  0.441 (+/- 0.022)
#
#                          train_score
# linear regression  0.457 (+/- 0.005)
# ridge              0.457 (+/- 0.005)

# %%
# lasso = make_pipeline(preprocessor,
#                       Lasso())
# results_dict["lasso"] = mean_std_cross_val_scores(
#     lasso, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %%
# elasticnet = make_pipeline(preprocessor,
#                            ElasticNet())
# results_dict["elastic net"] = mean_std_cross_val_scores(
#     elasticnet, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %% [markdown]
# #### Tree-based Models

# %%
# dt = make_pipeline(preprocessor, DecisionTreeRegressor())
# results_dict["decision tree"] = mean_std_cross_val_scores(
#     dt, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %%
# rf = make_pipeline(preprocessor, RandomForestRegressor(random_state=123))
# results_dict["random forest"] = mean_std_cross_val_scores(
#     rf, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %%
os.cpu_count()
# Out:
# 32

# %%
xgboost = make_pipeline(preprocessor, XGBRegressor(random_state=123, n_jobs=-1, verbosity=0))
results_dict["xgboost"] = mean_std_cross_val_scores(
    xgboost, X_train, y_train, return_train_score=True
)
pd.DataFrame(results_dict).T
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             fit_time         score_time         test_score  \
# linear regression  1.244 (+/- 0.049)  0.087 (+/- 0.004)  0.440 (+/- 0.022)
# ridge              0.790 (+/- 0.013)  0.085 (+/- 0.006)  0.441 (+/- 0.022)
# xgboost            0.909 (+/- 0.073)  0.118 (+/- 0.005)  0.596 (+/- 0.073)
#
#                          train_score
# linear regression  0.457 (+/- 0.005)
# ridge              0.457 (+/- 0.005)
# xgboost            0.878 (+/- 0.006)

# %% [markdown]
# #### Distance-based Models

# %%
# %%time
# knn = make_pipeline(preprocessor_with_scaler, KNeighborsRegressor())
# results_dict["knn"] = mean_std_cross_val_scores(
#     knn, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %%
# svr = make_pipeline(preprocessor_with_scaler, LinearSVR())
# results_dict["SVR"] = mean_std_cross_val_scores(
#     svr, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %% [markdown]
# It appears that gradient boosted tree model is outperforming the other models, with short training time.

# %% [markdown]
# ### Hyperparameter Optimization

# %%
# param_grid = {
#     "lgbmregressor__num_leaves": np.arange(100, 301, 10),
#     "lgbmregressor__learning_rate": np.arange(0.0001, 0.011, 0.001),
#     "lgbmregressor__n_estimators": np.arange(100, 301, 10)
# }

param_grid = {
    "xgbregressor__learning_rate": np.arange(0.0001, 1, 0.01),
    "xgbregressor__max_depth": np.arange(6, 100, 1),
    "xgbregressor__max_leaves": np.arange(0, 1501, 100),
    "xgbregressor__reg_gamma": np.arange(0, 20, 0.5),
    "xgbregressor__reg_lambda": np.arange(0, 10, 0.5),
    "xgbregressor__reg_alpha": np.arange(0, 10, 0.5)

}

# %%
random_search = RandomizedSearchCV(
    xgboost,
    param_distributions=param_grid,
    n_iter=100,
    n_jobs=-1,
    return_train_score=True,
    random_state=123
)

random_search.fit(X_train, y_train)
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# RandomizedSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                               ColumnTransformer(transformers=[('pipeline',
#                                                                                Pipeline(steps=[('onehotencoder',
#                                                                                                 OneHotEncoder(drop='if_binary',
#                                                                                                               handle_unknown='ignore'))]),
#                                                                                ['model',
#                                                                                 'movement',
#                                                                                 'case_material',
#                                                                                 'bracelet_material',
#                                                                                 'year_of_production',
#                                                                                 'year_is_approximated',
#                                                                                 'condition',
#                                                                                 'scope_of_delivery',
#                                                                                 'country',
#                                                                                 'avail...
#        6.5, 7. , 7.5, 8. , 8.5, 9. , 9.5]),
#                                         'xgbregressor__reg_gamma': array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#         5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5,
#        11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5, 16. ,
#        16.5, 17. , 17.5, 18. , 18.5, 19. , 19.5]),
#                                         'xgbregressor__reg_lambda': array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ,
#        6.5, 7. , 7.5, 8. , 8.5, 9. , 9.5])},
#                    random_state=123, return_train_score=True)

# %%
cv_result_df = pd.DataFrame(random_search.cv_results_)[
    [
        "mean_test_score",
        "param_xgbregressor__learning_rate",
        "param_xgbregressor__max_depth",
        "param_xgbregressor__max_leaves",
        "param_xgbregressor__reg_gamma",
        "param_xgbregressor__reg_lambda",
        "param_xgbregressor__reg_alpha",
        "mean_fit_time",
        "rank_test_score",
    ]
].set_index("rank_test_score").sort_index().T

cv_result_df.to_csv('xgboost_cv_result.csv')
cv_result_df
# Out:
# rank_test_score                         1         2         3         4    \
# mean_test_score                    0.613351  0.610349  0.607352    0.6063
# param_xgbregressor__learning_rate    0.2701    0.3101    0.7401    0.2701
# param_xgbregressor__max_depth            53         9         9        36
# param_xgbregressor__max_leaves          100      1000      1000       100
# param_xgbregressor__reg_gamma          14.5      10.0       5.0       1.0
# param_xgbregressor__reg_lambda          9.0       5.0       6.0       3.5
# param_xgbregressor__reg_alpha           1.0       6.5       0.5       5.5
# mean_fit_time                      2.419608  2.465455  2.553155  2.513701
#
# rank_test_score                         5         6         7         8    \
# mean_test_score                    0.599473  0.596093  0.593441  0.589416
# param_xgbregressor__learning_rate    0.1301    0.1001    0.9101    0.5601
# param_xgbregressor__max_depth            77        67        36        65
# param_xgbregressor__max_leaves          400       300       200       200
# param_xgbregressor__reg_gamma          18.0       5.5       6.5       9.0
# param_xgbregressor__reg_lambda          1.0       0.5       6.5       3.0
# param_xgbregressor__reg_alpha           7.0       6.5       2.5       6.5
# mean_fit_time                      5.735049  4.706646  3.752555  3.538437
#
# rank_test_score                         9         10   ...       91   \
# mean_test_score                    0.588831  0.588139  ...  0.534559
# param_xgbregressor__learning_rate    0.3101    0.4101  ...    0.8901
# param_xgbregressor__max_depth            34        58  ...        59
# param_xgbregressor__max_leaves          400       500  ...       600
# param_xgbregressor__reg_gamma          16.0       7.5  ...       2.5
# param_xgbregressor__reg_lambda          4.5       5.5  ...       1.0
# param_xgbregressor__reg_alpha           2.0       4.0  ...       7.5
# mean_fit_time                      5.735895  6.630708  ...  7.583348
#
# rank_test_score                          92         93         94   \
# mean_test_score                     0.533615   0.533379   0.526003
# param_xgbregressor__learning_rate     0.5301     0.9101     0.9801
# param_xgbregressor__max_depth             19         37         95
# param_xgbregressor__max_leaves          1400       1500          0
# param_xgbregressor__reg_gamma           17.5       14.0        8.5
# param_xgbregressor__reg_lambda           0.5        2.0        4.5
# param_xgbregressor__reg_alpha            8.0        4.0        1.0
# mean_fit_time                      11.330504  16.218141  63.447745
#
# rank_test_score                           95        96        97         98   \
# mean_test_score                      0.519029  0.518005  0.512624   0.491443
# param_xgbregressor__learning_rate      0.4701    0.8501    0.7101     0.0101
# param_xgbregressor__max_depth              81        19        59         75
# param_xgbregressor__max_leaves              0       800      1500       1100
# param_xgbregressor__reg_gamma            16.5      11.5      12.0        7.5
# param_xgbregressor__reg_lambda            0.5       0.5       0.0        2.0
# param_xgbregressor__reg_alpha             0.0       4.5       3.0        2.0
# mean_fit_time                      126.487538   9.21786  15.96618  13.134716
#
# rank_test_score                          99         100
# mean_test_score                     0.445149   0.419493
# param_xgbregressor__learning_rate     0.9701     0.9401
# param_xgbregressor__max_depth             32         92
# param_xgbregressor__max_leaves          1100        900
# param_xgbregressor__reg_gamma           11.5       12.5
# param_xgbregressor__reg_lambda           0.0        0.0
# param_xgbregressor__reg_alpha            5.5        3.5
# mean_fit_time                      12.356324  10.049223
#
# [8 rows x 100 columns]

# %%
random_search.best_estimator_.named_steps['xgbregressor'].save_model('model/xgboost_opt.model')
random_search.best_estimator_.named_steps['xgbregressor'].best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 2
#       1 random_search.best_estimator_.named_steps['xgbregressor'].save_model('model/xgboost_opt.model')
# ----> 2 random_search.best_estimator_.named_steps['xgbregressor'].best_params_
#
# AttributeError: 'XGBRegressor' object has no attribute 'best_params_'

# %%
xgboost_test = XGBRegressor()
xgboost_test.load_model('model/xgboost_opt.model')
xgboost_test
# Out:
# XGBRegressor(base_score='3.1600467E4', booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgboost_opt = make_pipeline(random_search.best_estimator_)
results_dict["xgboost optimized"] = mean_std_cross_val_scores(
    xgboost_opt, X_train, y_train, return_train_score=True
)
pd.DataFrame(results_dict).T
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             fit_time         score_time         test_score  \
# linear regression  1.244 (+/- 0.049)  0.087 (+/- 0.004)  0.440 (+/- 0.022)
# ridge              0.790 (+/- 0.013)  0.085 (+/- 0.006)  0.441 (+/- 0.022)
# xgboost            0.909 (+/- 0.073)  0.118 (+/- 0.005)  0.596 (+/- 0.073)
# xgboost optimized  1.282 (+/- 0.009)  0.143 (+/- 0.005)  0.613 (+/- 0.055)
#
#                          train_score
# linear regression  0.457 (+/- 0.005)
# ridge              0.457 (+/- 0.005)
# xgboost            0.878 (+/- 0.006)
# xgboost optimized  0.858 (+/- 0.012)

# %%
xgboost_opt.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('columntransformer',
#                                   ColumnTransformer(transformers=[('pipeline',
#                                                                    Pipeline(steps=[('onehotencoder',
#                                                                                     OneHotEncoder(drop='if_binary',
#                                                                                                   handle_unknown='ignore'))]),
#                                                                    ['model',
#                                                                     'movement',
#                                                                     'case_material',
#                                                                     'bracelet_material',
#                                                                     'year_of_production',
#                                                                     'year_is_approximated',
#                                                                     'condition',
#                                                                     'scope_of_delivery',
#                                                                     'country',
#                                                                     'availa...
#                                                grow_policy=None,
#                                                importance_type=None,
#                                                interaction_constraints=None,
#                                                learning_rate=0.2701,
#                                                max_bin=None,
#                                                max_cat_threshold=None,
#                                                max_cat_to_onehot=None,
#                                                max_delta_step=None,
#                                                max_depth=53, max_leaves=100,
#                                                min_child_weight=None,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=None, n_jobs=-1,
#                                                num_parallel_tree=None,
#                                                random_state=123, ...))]))])

# %%
xgboost_opt.__sklearn_is_fitted__()
# Out:
# True

# %%
xgboost_opt.named_steps['pipeline'].named_steps['xgbregressor'].save_model('xgboost_opt.json')
display(xgboost_opt.named_steps['pipeline'].named_steps['xgbregressor'])
xgboost_test = XGBRegressor()
xgboost_test.load_model('xgboost_opt.json')
xgboost_test
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2701, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=53, max_leaves=100,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=-1,
#              num_parallel_tree=None, random_state=123, ...)
# XGBRegressor(base_score='3.1600467E4', booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
random_search.best_estimator_.named_steps['xgbregressor']
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2701, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=53, max_leaves=100,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=-1,
#              num_parallel_tree=None, random_state=123, ...)

# %%
import pickle

# Save the entire pipeline model to a file using pickle
with open('xgboost_opt.pkl', 'wb') as file:
    pickle.dump(random_search.best_estimator_.named_steps['xgbregressor'], file)

# Load the entire pipeline model from a file using pickle
with open('xgboost_opt.pkl', 'rb') as file:
    xgboost_test = pickle.load(file)

# %%
xgboost_test
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2701, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=53, max_leaves=100,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=-1,
#              num_parallel_tree=None, random_state=123, ...)

# %%
xgboost_test = make_pipeline(preprocessor, xgboost_test)
results_dict["xgboost test"] = mean_std_cross_val_scores(
    xgboost_test, X_train, y_train, return_train_score=True
)
pd.DataFrame(results_dict).T
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8, 10] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [4, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 6, 8, 10, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 4, 8, 14, 15] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             fit_time         score_time         test_score  \
# linear regression  1.244 (+/- 0.049)  0.087 (+/- 0.004)  0.440 (+/- 0.022)
# ridge              0.790 (+/- 0.013)  0.085 (+/- 0.006)  0.441 (+/- 0.022)
# xgboost            0.909 (+/- 0.073)  0.118 (+/- 0.005)  0.596 (+/- 0.073)
# xgboost optimized  1.282 (+/- 0.009)  0.143 (+/- 0.005)  0.613 (+/- 0.055)
# xgboost test       1.250 (+/- 0.006)  0.141 (+/- 0.006)  0.613 (+/- 0.055)
#
#                          train_score
# linear regression  0.457 (+/- 0.005)
# ridge              0.457 (+/- 0.005)
# xgboost            0.878 (+/- 0.006)
# xgboost optimized  0.858 (+/- 0.012)
# xgboost test       0.858 (+/- 0.012)
