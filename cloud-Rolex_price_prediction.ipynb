# %% [markdown]
# # Rolex Listing Price Prediction based on model and complications

# %%
import pandas as pd
import numpy as np
import glob
import janitor
import altair as alt
import matplotlib as plt
alt.data_transformers.enable("vegafusion")
# Out:
# DataTransformerRegistry.enable('vegafusion')

# %%
# def warn(*args, **kwargs):
#     pass
import warnings
# warnings.warn = warn

# Specifically suppress the UserWarnings related to unknown categories in OneHotEncoder
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Cleaning

# %%
files = glob.glob('data/result_df/*.csv')
dirty_df = pd.concat((pd.read_csv(file, index_col=0)
                for file in files)
              )

dirty_df = dirty_df.clean_names()
dirty_df.drop_duplicates(subset=['listing_code', 'reference_number'], inplace=True)
dirty_df.dropna(subset=['brand', 'model', 'listing_code', 'price', 'title', 'subtitle', 'case_diameter'], inplace=True)
dirty_df.reset_index(drop=True, inplace=True)


dirty_df.head()
# Out:
#   listing_code  brand          model  \
# 0       IJD7R3  Rolex    Datejust 41
# 1       HOAOQ5  Rolex    Datejust 31
# 2       IJ9RY8  Rolex    Datejust 36
# 3       FDHJM3  Rolex  GMT-Master II
# 4       FFF9D3  Rolex       Explorer
#
#                                 reference_number   movement case_material  \
# 0  126331 NEW UNWORN 2023 Wimbledon 41mm Jubilee  Automatic    Gold/Steel
# 1                                         278271  Automatic    Gold/Steel
# 2                                         126231  Automatic    Gold/Steel
# 3                                     126710BLNR  Automatic         Steel
# 4                                         124270  Automatic         Steel
#
#   bracelet_material year_of_production  \
# 0        Gold/Steel               2023
# 1        Gold/Steel               2023
# 2        Gold/Steel               2023
# 3             Steel               2023
# 4             Steel               2021
#
#                                            condition  \
# 0        New\n(Brand new, without any signs of wear)
# 1        New\n(Brand new, without any signs of wear)
# 2        New\n(Brand new, without any signs of wear)
# 3        New\n(Brand new, without any signs of wear)
# 4  Very good\n(Worn with little to no signs of wear)
#
#                scope_of_delivery  ... thickness lug_width buckle_width  \
# 0  Original box, original papers  ...       NaN       NaN          NaN
# 1  Original box, original papers  ...       NaN       NaN          NaN
# 2  Original box, original papers  ...       NaN       NaN          NaN
# 3  Original box, original papers  ...       NaN       NaN          NaN
# 4  Original box, original papers  ...       NaN       NaN          NaN
#
#   frequency bracelet_thickness submariner_kermit_ref_ day_date_ref_  \
# 0       NaN                NaN                    NaN           NaN
# 1       NaN                NaN                    NaN           NaN
# 2       NaN                NaN                    NaN           NaN
# 3       NaN                NaN                    NaN           NaN
# 4       NaN                NaN                    NaN           NaN
#
#    datejust_reference_number submariner_date_reference reference
# 0                        NaN                       NaN       NaN
# 1                        NaN                       NaN       NaN
# 2                        NaN                       NaN       NaN
# 3                        NaN                       NaN       NaN
# 4                        NaN                       NaN       NaN
#
# [5 rows x 48 columns]

# %%
# clean case_diameter
def is_convertible_to_int(value):
    try:
        int(value)
        return True
    except ValueError:
        return False

convertible_mask = dirty_df['case_diameter'].str[:2].apply(is_convertible_to_int)

dirty_df = dirty_df[convertible_mask]

dirty_df['case_diameter'] = dirty_df['case_diameter'].str[:2].astype('int')

# %%
# add column of whether the price is negotiable
dirty_df.insert(loc=13, column='is_negotiable', value=dirty_df['price'].str.contains('Negotiable', case=False).astype(int))

# %%
# keep only CA$ in the `price` column
dirty_df['price'] = dirty_df['price'].str.extract('C\$([0-9,]+)')[0].str.replace(',', '')
dirty_df['price'] = pd.to_numeric(dirty_df['price'], errors='coerce')
dirty_df['price'].fillna(0, inplace=True)
dirty_df['price'] = dirty_df['price'].astype(int)

dirty_df = dirty_df.query('price != 0')

# %%
# add column of whether the year of production is approximated
dirty_df.insert(loc=8, column='year_is_approximated', value=dirty_df['year_of_production'].str.contains('Approximation', case=False).astype(int))

# Clean year of production
dirty_df['year_of_production'] = dirty_df['year_of_production'].apply(lambda x: x[:4] if x != 'Unknown' else x)
dirty_df['year_of_production'] = dirty_df['year_of_production'].replace('Unknown', np.nan)
dirty_df['year_of_production'] = pd.to_numeric(dirty_df['year_of_production'], errors='coerce')

# %%
# convert scope of delivery to string
# dirty_df['scope_of_delivery'] = dirty_df['scope_of_delivery'].astype('category')

# %%
# simplify the location to country only
dirty_df['country'] = dirty_df['location'].str.split(',').str[0]

# %% [markdown]
# Save the cleaned data locally

# %%
rolex_df = dirty_df
rolex_df.to_csv('data/rolex_df.csv')

# %% [markdown]
# ## EDA

# %%
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split

# %%
display(rolex_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62495 entries, 0 to 66279
# Data columns (total 51 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   listing_code                          62495 non-null  object
#  1   brand                                 62495 non-null  object
#  2   model                                 62495 non-null  object
#  3   reference_number                      61846 non-null  object
#  4   movement                              61443 non-null  object
#  5   case_material                         60862 non-null  object
#  6   bracelet_material                     56783 non-null  object
#  7   year_of_production                    46712 non-null  float64
#  8   year_is_approximated                  62495 non-null  int32
#  9   condition                             61537 non-null  object
#  10  scope_of_delivery                     62495 non-null  object
#  11  gender                                55576 non-null  object
#  12  location                              62495 non-null  object
#  13  price                                 62495 non-null  int32
#  14  is_negotiable                         62495 non-null  int32
#  15  availability                          62495 non-null  object
#  16  caliber_movement                      41482 non-null  object
#  17  base_caliber                          23925 non-null  object
#  18  power_reserve                         37823 non-null  object
#  19  number_of_jewels                      37490 non-null  float64
#  20  case_diameter                         62495 non-null  int32
#  21  water_resistance                      45808 non-null  object
#  22  bezel_material                        46054 non-null  object
#  23  crystal                               50999 non-null  object
#  24  dial                                  57611 non-null  object
#  25  dial_numerals                         37784 non-null  object
#  26  bracelet_color                        48105 non-null  object
#  27  clasp                                 45501 non-null  object
#  28  clasp_material                        39953 non-null  object
#  29  functions                             40925 non-null  object
#  30  title                                 62495 non-null  object
#  31  subtitle                              62495 non-null  object
#  32  rating                                56618 non-null  float64
#  33  reviews                               62495 non-null  int64
#  34  description                           55560 non-null  object
#  35  dealer_product_code                   32760 non-null  object
#  36  bracelet_length                       4514 non-null   object
#  37  alternative_reference_numbers         0 non-null      object
#  38  rolex_lady_datejust_reference_number  0 non-null      object
#  39  model_reference_number                0 non-null      object
#  40  thickness                             5957 non-null   object
#  41  lug_width                             3114 non-null   object
#  42  buckle_width                          582 non-null    object
#  43  frequency                             1452 non-null   object
#  44  bracelet_thickness                    301 non-null    object
#  45  submariner_kermit_ref_                0 non-null      object
#  46  day_date_ref_                         0 non-null      object
#  47  datejust_reference_number             0 non-null      object
#  48  submariner_date_reference             0 non-null      object
#  49  reference                             0 non-null      object
#  50  country                               62495 non-null  object
# dtypes: float64(3), int32(4), int64(1), object(43)
# memory usage: 23.8+ MB
# None

# %%
df = rolex_df[['model', 'movement', 'case_material', 'bracelet_material',
               'year_of_production', 'year_is_approximated', 'condition', 'scope_of_delivery',
               'country', 'availability', 'case_diameter', 'bezel_material',
               'crystal', 'dial', 'bracelet_color', 'clasp', 'clasp_material',
               'rating', 'reviews', 'price', 'is_negotiable']]
df.head(1)
# Out:
#          model   movement case_material bracelet_material  year_of_production  \
# 0  Datejust 41  Automatic    Gold/Steel        Gold/Steel              2023.0
#
#    year_is_approximated                                    condition  \
# 0                     0  New\n(Brand new, without any signs of wear)
#
#                scope_of_delivery                   country      availability  \
# 0  Original box, original papers  United States of America  Item is in stock
#
#    ...  bezel_material           crystal    dial bracelet_color       clasp  \
# 0  ...       Rose gold  Sapphire crystal  Silver     Gold/Steel  Fold clasp
#
#   clasp_material rating  reviews  price  is_negotiable
# 0     Gold/Steel    4.2       11  23421              1
#
# [1 rows x 21 columns]

# %%
df.shape
# Out:
# (62495, 21)

# %% [markdown]
# We will use only the following columns since they have fewer missing values and have more variation even for the same model. Features that are unrelated to the watch model is especially interesting, such as `condition` and `scope_of_delivery`, as they provide insights on how these factor in to the listing price.

# %%
train_df, test_df = train_test_split(df, test_size=0.2, random_state=123)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49996, 21)
# (12499, 21)

# %%
X_train, y_train = train_df.drop(
    columns=["price"]), train_df["price"]
y_train = pd.DataFrame(y_train)
X_test, y_test = test_df.drop(
    columns=["price"]), test_df["price"]
y_test = pd.DataFrame(y_test)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (49996, 20)
# (49996, 1)
# (12499, 20)
# (12499, 1)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49996 entries, 749 to 56465
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 49996 non-null  object
#  1   movement              49159 non-null  object
#  2   case_material         48678 non-null  object
#  3   bracelet_material     45462 non-null  object
#  4   year_of_production    37355 non-null  float64
#  5   year_is_approximated  49996 non-null  int32
#  6   condition             49234 non-null  object
#  7   scope_of_delivery     49996 non-null  object
#  8   country               49996 non-null  object
#  9   availability          49996 non-null  object
#  10  case_diameter         49996 non-null  int32
#  11  bezel_material        36838 non-null  object
#  12  crystal               40790 non-null  object
#  13  dial                  46103 non-null  object
#  14  bracelet_color        38567 non-null  object
#  15  clasp                 36415 non-null  object
#  16  clasp_material        31975 non-null  object
#  17  rating                45316 non-null  float64
#  18  reviews               49996 non-null  int64
#  19  is_negotiable         49996 non-null  int32
# dtypes: float64(2), int32(3), int64(1), object(14)
# memory usage: 7.4+ MB

# %%
plot_columns = X_train.columns.to_list()

for column in plot_columns:
    top_categories = X_train[column].value_counts().head(10).index
    filtered_X_train = X_train[X_train[column].isin(top_categories)]

    chart = alt.Chart(filtered_X_train).mark_bar().encode(
        y=alt.Y(f"{column}:N", sort='-x'),
        x=alt.X('count()', title='Count')
    ).properties(
        title=f"Top 10 Categories in {column}"
    )
    
    chart.display()
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
y_train.describe(percentiles=[.25, .5, .75, 0.975]).apply(lambda s: s.apply('{0:.0f}'.format))
# Out:
#          price
# count    49996
# mean     31688
# std      43378
# min         88
# 25%      13116
# 50%      20680
# 75%      33713
# 97.5%   118977
# max    1506426

# %%
alt.Chart(y_train.query('price <= 120000'),
          title='Histogram of Rolex price').mark_bar().encode(
    alt.X('price:Q').bin(maxbins=40),
    y='count()'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# The above histogram is showing at least 97.5% of the price data. It is difficult to interpret the distribution with the outliers so they are disregarded for the purpose of this visualization.

# %%
train_df.corr(numeric_only=True).round(
    decimals=3).style.background_gradient()
# Out:
# <style type="text/css">
# #T_90d49_row0_col0, #T_90d49_row1_col1, #T_90d49_row2_col2, #T_90d49_row3_col3, #T_90d49_row4_col4, #T_90d49_row5_col5, #T_90d49_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_90d49_row0_col1, #T_90d49_row1_col0, #T_90d49_row4_col2, #T_90d49_row4_col5, #T_90d49_row4_col6, #T_90d49_row5_col3, #T_90d49_row6_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_90d49_row0_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_90d49_row0_col3, #T_90d49_row1_col5 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_90d49_row0_col4 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_90d49_row0_col5 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_90d49_row0_col6 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_90d49_row1_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_90d49_row1_col3, #T_90d49_row2_col3, #T_90d49_row2_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_90d49_row1_col4 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_90d49_row1_col6 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_90d49_row2_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_90d49_row2_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_90d49_row2_col5 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_90d49_row2_col6, #T_90d49_row3_col1, #T_90d49_row4_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_90d49_row3_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_90d49_row3_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_90d49_row3_col4 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_90d49_row3_col5, #T_90d49_row5_col4, #T_90d49_row6_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_90d49_row3_col6 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_90d49_row4_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_90d49_row4_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_90d49_row5_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_90d49_row5_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_90d49_row5_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_90d49_row5_col6, #T_90d49_row6_col0, #T_90d49_row6_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_90d49_row6_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_90d49_row6_col5 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# </style>
# <table id="T_90d49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90d49_level0_col0" class="col_heading level0 col0" >year_of_production</th>
#       <th id="T_90d49_level0_col1" class="col_heading level0 col1" >year_is_approximated</th>
#       <th id="T_90d49_level0_col2" class="col_heading level0 col2" >case_diameter</th>
#       <th id="T_90d49_level0_col3" class="col_heading level0 col3" >rating</th>
#       <th id="T_90d49_level0_col4" class="col_heading level0 col4" >reviews</th>
#       <th id="T_90d49_level0_col5" class="col_heading level0 col5" >price</th>
#       <th id="T_90d49_level0_col6" class="col_heading level0 col6" >is_negotiable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90d49_level0_row0" class="row_heading level0 row0" >year_of_production</th>
#       <td id="T_90d49_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_90d49_row0_col1" class="data row0 col1" >-0.161000</td>
#       <td id="T_90d49_row0_col2" class="data row0 col2" >0.319000</td>
#       <td id="T_90d49_row0_col3" class="data row0 col3" >0.022000</td>
#       <td id="T_90d49_row0_col4" class="data row0 col4" >0.014000</td>
#       <td id="T_90d49_row0_col5" class="data row0 col5" >0.133000</td>
#       <td id="T_90d49_row0_col6" class="data row0 col6" >-0.015000</td>
#     </tr>
#     <tr>
#       <th id="T_90d49_level0_row1" class="row_heading level0 row1" >year_is_approximated</th>
#       <td id="T_90d49_row1_col0" class="data row1 col0" >-0.161000</td>
#       <td id="T_90d49_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_90d49_row1_col2" class="data row1 col2" >-0.074000</td>
#       <td id="T_90d49_row1_col3" class="data row1 col3" >0.013000</td>
#       <td id="T_90d49_row1_col4" class="data row1 col4" >0.264000</td>
#       <td id="T_90d49_row1_col5" class="data row1 col5" >-0.029000</td>
#       <td id="T_90d49_row1_col6" class="data row1 col6" >0.068000</td>
#     </tr>
#     <tr>
#       <th id="T_90d49_level0_row2" class="row_heading level0 row2" >case_diameter</th>
#       <td id="T_90d49_row2_col0" class="data row2 col0" >0.319000</td>
#       <td id="T_90d49_row2_col1" class="data row2 col1" >-0.074000</td>
#       <td id="T_90d49_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_90d49_row2_col3" class="data row2 col3" >0.014000</td>
#       <td id="T_90d49_row2_col4" class="data row2 col4" >-0.091000</td>
#       <td id="T_90d49_row2_col5" class="data row2 col5" >0.224000</td>
#       <td id="T_90d49_row2_col6" class="data row2 col6" >0.047000</td>
#     </tr>
#     <tr>
#       <th id="T_90d49_level0_row3" class="row_heading level0 row3" >rating</th>
#       <td id="T_90d49_row3_col0" class="data row3 col0" >0.022000</td>
#       <td id="T_90d49_row3_col1" class="data row3 col1" >0.013000</td>
#       <td id="T_90d49_row3_col2" class="data row3 col2" >0.014000</td>
#       <td id="T_90d49_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_90d49_row3_col4" class="data row3 col4" >0.099000</td>
#       <td id="T_90d49_row3_col5" class="data row3 col5" >-0.012000</td>
#       <td id="T_90d49_row3_col6" class="data row3 col6" >0.038000</td>
#     </tr>
#     <tr>
#       <th id="T_90d49_level0_row4" class="row_heading level0 row4" >reviews</th>
#       <td id="T_90d49_row4_col0" class="data row4 col0" >0.014000</td>
#       <td id="T_90d49_row4_col1" class="data row4 col1" >0.264000</td>
#       <td id="T_90d49_row4_col2" class="data row4 col2" >-0.091000</td>
#       <td id="T_90d49_row4_col3" class="data row4 col3" >0.099000</td>
#       <td id="T_90d49_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_90d49_row4_col5" class="data row4 col5" >-0.063000</td>
#       <td id="T_90d49_row4_col6" class="data row4 col6" >-0.118000</td>
#     </tr>
#     <tr>
#       <th id="T_90d49_level0_row5" class="row_heading level0 row5" >price</th>
#       <td id="T_90d49_row5_col0" class="data row5 col0" >0.133000</td>
#       <td id="T_90d49_row5_col1" class="data row5 col1" >-0.029000</td>
#       <td id="T_90d49_row5_col2" class="data row5 col2" >0.224000</td>
#       <td id="T_90d49_row5_col3" class="data row5 col3" >-0.012000</td>
#       <td id="T_90d49_row5_col4" class="data row5 col4" >-0.063000</td>
#       <td id="T_90d49_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_90d49_row5_col6" class="data row5 col6" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_90d49_level0_row6" class="row_heading level0 row6" >is_negotiable</th>
#       <td id="T_90d49_row6_col0" class="data row6 col0" >-0.015000</td>
#       <td id="T_90d49_row6_col1" class="data row6 col1" >0.068000</td>
#       <td id="T_90d49_row6_col2" class="data row6 col2" >0.047000</td>
#       <td id="T_90d49_row6_col3" class="data row6 col3" >0.038000</td>
#       <td id="T_90d49_row6_col4" class="data row6 col4" >-0.118000</td>
#       <td id="T_90d49_row6_col5" class="data row6 col5" >0.022000</td>
#       <td id="T_90d49_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The price seems to be slightly positively correlated with case diameter, which is expected as larger models are usually equipped with more complications that drive up the price.

# %% [markdown]
# ## Models

# %% [markdown]
# ### Preprocessing

# %%
# imports
import sys, os
import time

import numpy as np
import pandas as pd
import altair as alt
from IPython.display import HTML

sys.path.append(os.path.join(os.path.abspath("."), "code"))

from IPython.display import display

# Classifiers and regressors
from sklearn.dummy import DummyClassifier, DummyRegressor

# Preprocessing and pipeline
from sklearn.impute import SimpleImputer

# train test split and cross validation
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.preprocessing import (
    MinMaxScaler,
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import *
from sklearn.tree import *
from sklearn.ensemble import *
from sklearn.svm import *
from lightgbm.sklearn import *
from sklearn.model_selection import *
from xgboost import XGBRegressor

# %%
# adapted from 571 lecture notes
# code from lecture
def mean_std_cross_val_scores(model, X_train, y_train, **kwargs):
    """
    Returns mean and std of cross validation

    Parameters
    ----------
    model :
        scikit-learn model
    X_train : numpy array or pandas DataFrame
        X in the training data
    y_train :
        y in the training data

    Returns
    ----------
        pandas Series with mean scores from cross_validation
    """

    scores = cross_validate(model, X_train, y_train, n_jobs=-1, **kwargs)

    mean_scores = pd.DataFrame(scores).mean()
    std_scores = pd.DataFrame(scores).std()
    out_col = []

    for i in range(len(mean_scores)):
        out_col.append((f"%0.3f (+/- %0.3f)" %
                       (mean_scores.iloc[i], std_scores.iloc[i])))

    return pd.Series(data=out_col, index=mean_scores.index)

# %% [markdown]
# One-hot encoding is applied on categorical features and scaling on numerical features. The preprocesspr with scaler is used only for distance-based models that are sensitive to units in features. It is easier to interpret the feature importance with unscaled data when using models that are robust to such data.

# %%
categorcial_feats = [col for col in X_train.columns if col not in ['case_diameter', 'rating', 'reviews', 'year_of_production']]
numerical_feats = ['case_diameter', 'rating', 'reviews', 'year_of_production']

categorical_pipe = make_pipeline(OneHotEncoder(drop='if_binary', handle_unknown='ignore'))
numerical_pipe = make_pipeline(StandardScaler(), SimpleImputer(strategy='median'))

preprocessor = make_column_transformer((categorical_pipe, categorcial_feats))
preprocessor_with_scaler = make_column_transformer((categorical_pipe, categorcial_feats),
                                                    (numerical_pipe, numerical_feats))
preprocessor_with_scaler
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('onehotencoder',
#                                                   OneHotEncoder(drop='if_binary',
#                                                                 handle_unknown='ignore'))]),
#                                  ['model', 'movement', 'case_material',
#                                   'bracelet_material', 'year_is_approximated',
#                                   'condition', 'scope_of_delivery', 'country',
#                                   'availability', 'bezel_material', 'crystal',
#                                   'dial', 'bracelet_color', 'clasp',
#                                   'clasp_material', 'is_negotiable']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('standardscaler',
#                                                   StandardScaler()),
#                                                  ('simpleimputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  ['case_diameter', 'rating', 'reviews',
#                                   'year_of_production'])])

# %% [markdown]
# ### Model Fitting

# %%
# create a dictionary for storing model scores
results_dict = {}

# %% [markdown]
# #### Baseline - Simple Linear Regression

# %%
linear_reg = make_pipeline(preprocessor,
                           LinearRegression(n_jobs=-1))
results_dict["linear regression"] = mean_std_cross_val_scores(
    linear_reg, X_train, y_train, return_train_score=True
)
pd.DataFrame(results_dict).T
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             fit_time         score_time         test_score  \
# linear regression  1.126 (+/- 0.088)  0.106 (+/- 0.024)  0.436 (+/- 0.030)
#
#                          train_score
# linear regression  0.443 (+/- 0.007)

# %% [markdown]
# #### Classical Linear Regression Models: Ridge and Lasso

# %%
ridge = make_pipeline(preprocessor,
                      Ridge())
results_dict["ridge"] = mean_std_cross_val_scores(
    ridge, X_train, y_train, return_train_score=True
)
pd.DataFrame(results_dict).T
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             fit_time         score_time         test_score  \
# linear regression  1.126 (+/- 0.088)  0.106 (+/- 0.024)  0.436 (+/- 0.030)
# ridge              0.743 (+/- 0.024)  0.085 (+/- 0.004)  0.437 (+/- 0.030)
#
#                          train_score
# linear regression  0.443 (+/- 0.007)
# ridge              0.443 (+/- 0.007)

# %%
# lasso = make_pipeline(preprocessor,
#                       Lasso())
# results_dict["lasso"] = mean_std_cross_val_scores(
#     lasso, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %%
# elasticnet = make_pipeline(preprocessor,
#                            ElasticNet())
# results_dict["elastic net"] = mean_std_cross_val_scores(
#     elasticnet, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %% [markdown]
# #### Tree-based Models

# %%
# dt = make_pipeline(preprocessor, DecisionTreeRegressor())
# results_dict["decision tree"] = mean_std_cross_val_scores(
#     dt, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %%
# rf = make_pipeline(preprocessor, RandomForestRegressor(random_state=123))
# results_dict["random forest"] = mean_std_cross_val_scores(
#     rf, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %%
xgboost = make_pipeline(preprocessor_with_scaler, XGBRegressor(objective='reg:gamma', random_state=123, n_jobs=-1, verbosity=0))
results_dict["xgboost"] = mean_std_cross_val_scores(
    xgboost, X_train, y_train, return_train_score=True
)
pd.DataFrame(results_dict).T
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             fit_time         score_time         test_score  \
# linear regression  1.126 (+/- 0.088)  0.106 (+/- 0.024)  0.436 (+/- 0.030)
# ridge              0.743 (+/- 0.024)  0.085 (+/- 0.004)  0.437 (+/- 0.030)
# xgboost            1.230 (+/- 0.009)  0.143 (+/- 0.007)  0.585 (+/- 0.052)
# xgboost optimized  1.396 (+/- 0.014)  0.179 (+/- 0.006)  0.646 (+/- 0.072)
#
#                          train_score
# linear regression  0.443 (+/- 0.007)
# ridge              0.443 (+/- 0.007)
# xgboost            0.680 (+/- 0.008)
# xgboost optimized  0.845 (+/- 0.008)

# %%
# from sklearn.feature_selection import SelectKBest

# xgboost_feat_select = make_pipeline(preprocessor_with_scaler,
#                                     SelectKBest(k=230),
#                                     XGBRegressor(random_state=123, verbosity=0))
# results_dict["xgboost feat select"] = mean_std_cross_val_scores(
#     xgboost_feat_select, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %% [markdown]
# #### Distance-based Models

# %%
# %%time
# knn = make_pipeline(preprocessor_with_scaler, KNeighborsRegressor())
# results_dict["knn"] = mean_std_cross_val_scores(
#     knn, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %%
# svr = make_pipeline(preprocessor_with_scaler, LinearSVR())
# results_dict["SVR"] = mean_std_cross_val_scores(
#     svr, X_train, y_train, return_train_score=True
# )
# pd.DataFrame(results_dict).T

# %% [markdown]
# It appears that gradient boosted tree model is outperforming the other models, with short training time.

# %% [markdown]
# ### Hyperparameter Optimization

# %%
TUNING = True

# %%
param_grid = {
    "xgbregressor__learning_rate": np.arange(0.1, 1, 0.05),
    "xgbregressor__max_depth": np.arange(6, 20, 1),
    "xgbregressor__max_leaves": np.arange(300, 2001, 50),
    "xgbregressor__n_estimators": np.arange(100, 2001, 50),
    # "xgbregressor__gamma": np.arange(0, 100, 0.5),
    "xgbregressor__lambda": np.arange(0, 100, 0.5),
    # "xgbregressor__alpha": np.arange(0, 100, 0.5)

}

# %%
if TUNING:
    random_search = RandomizedSearchCV(
    xgboost,
    param_distributions=param_grid,
    n_iter=500,
    n_jobs=-1,
    return_train_score=True,
    random_state=123
    )

    random_search.fit(X_train, y_train)
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
if TUNING:
    cv_result_df = pd.DataFrame(random_search.cv_results_)[
        [
            "mean_test_score",
            "param_xgbregressor__learning_rate",
            "param_xgbregressor__max_depth",
            "param_xgbregressor__max_leaves",
            "param_xgbregressor__n_estimators",
            # "param_xgbregressor__gamma",
            "param_xgbregressor__lambda",
            # "param_xgbregressor__alpha",
            "mean_fit_time",
            "rank_test_score",
        ]
    ].set_index("rank_test_score").sort_index().T

    cv_result_df.to_csv('model/xgboost_cv_result.csv')
    cv_result_df
else:
    cv_result_df = pd.read_csv('model/xgboost_cv_result.csv', index_col=0)

cv_result_df
# Out:
# rank_test_score                          1          2          3          4    \
# mean_test_score                      0.66434   0.656683   0.654874   0.654582
# param_xgbregressor__learning_rate      0.341      0.421      0.281      0.201
# param_xgbregressor__max_depth             19          8         10         12
# param_xgbregressor__max_leaves           500       1800        800        850
# param_xgbregressor__n_estimators        1300        500       1700        600
# param_xgbregressor__lambda              96.5       31.5       54.0       33.0
# param_xgbregressor__alpha                1.5        0.5        1.5        0.0
# mean_fit_time                      36.110154  10.941848  28.999308  20.418665
#
# rank_test_score                          5          6          7          8    \
# mean_test_score                      0.65165   0.650637   0.650572   0.650073
# param_xgbregressor__learning_rate      0.741      0.061      0.181      0.461
# param_xgbregressor__max_depth              8         19         16         12
# param_xgbregressor__max_leaves          1900       1050        550       1050
# param_xgbregressor__n_estimators        1700        950        700        250
# param_xgbregressor__lambda              42.5       78.0       41.5       37.0
# param_xgbregressor__alpha                1.5        2.5        2.0        2.5
# mean_fit_time                      27.076131  67.010197  28.059022  10.418494
#
# rank_test_score                         9          10   ...       491  \
# mean_test_score                    0.649804   0.648693  ...  -0.54216
# param_xgbregressor__learning_rate     0.761      0.541  ...     0.001
# param_xgbregressor__max_depth             7         12  ...         6
# param_xgbregressor__max_leaves         1350        650  ...       450
# param_xgbregressor__n_estimators        600       1550  ...      1550
# param_xgbregressor__lambda             78.5       34.0  ...      95.5
# param_xgbregressor__alpha               1.0        3.5  ...      19.0
# mean_fit_time                      12.43209  18.152969  ...  9.395872
#
# rank_test_score                         492       493       494       495  \
# mean_test_score                   -0.542305  -0.54237  -0.54237 -0.542381
# param_xgbregressor__learning_rate     0.001     0.001     0.001     0.001
# param_xgbregressor__max_depth             7         8        10         8
# param_xgbregressor__max_leaves          450       700      1850      1700
# param_xgbregressor__n_estimators       1150       900       900       850
# param_xgbregressor__lambda             41.0      21.5      61.5      99.0
# param_xgbregressor__alpha              33.5      45.5      77.0       4.5
# mean_fit_time                      7.334755  5.831402  5.963985  5.626815
#
# rank_test_score                         496       497       498       499  \
# mean_test_score                   -0.542381 -0.542381  -0.54246 -0.542467
# param_xgbregressor__learning_rate     0.001     0.001     0.001     0.001
# param_xgbregressor__max_depth            13        19        16         7
# param_xgbregressor__max_leaves         1500      1900      1450      2000
# param_xgbregressor__n_estimators        850       850       400       350
# param_xgbregressor__lambda             68.0      93.0      14.0      58.5
# param_xgbregressor__alpha              71.0      80.5      60.5      78.5
# mean_fit_time                      5.702136  5.492291  3.054985  2.822632
#
# rank_test_score                         500
# mean_test_score                   -0.542473
# param_xgbregressor__learning_rate     0.001
# param_xgbregressor__max_depth            13
# param_xgbregressor__max_leaves          650
# param_xgbregressor__n_estimators        300
# param_xgbregressor__lambda             95.0
# param_xgbregressor__alpha              97.0
# mean_fit_time                       2.59081
#
# [8 rows x 500 columns]

# %%
import pickle
# Extract the best models
# `cv_results_` attribute provides a lot of information about the search
results = random_search.cv_results_
scores = results['mean_test_score']
indices = list(range(len(scores)))

# Sort the indices of the scores, in descending order of scores
sorted_indices = sorted(indices, key=lambda i: scores[i], reverse=True)

# Save the top 5 models
top_n = 5  # Number of top models to save
for rank, index in enumerate(sorted_indices[:top_n], start=1):
    model_params = results['params'][index]
    model_score = scores[index]
    model = random_search.estimator.set_params(**model_params)
    model.fit(X_train, y_train)  # Refit the model with the best parameters on the full training set
    
    # Save the model using pickle
    filename = f'model_rank_{rank}_score_{model_score:.4f}.pkl'
    with open(filename, 'wb') as file:
        pickle.dump(model, file)
    print(f"Saved: {filename} - Score: {model_score:.4f}")
# Out:
# Saved: model_rank_1_score_0.6463.pkl - Score: 0.6463
# Saved: model_rank_2_score_0.6459.pkl - Score: 0.6459
# Saved: model_rank_3_score_0.6455.pkl - Score: 0.6455
# Saved: model_rank_4_score_0.6415.pkl - Score: 0.6415
# Saved: model_rank_5_score_0.6411.pkl - Score: 0.6411

# %%
import altair as alt

fig_hyperparam = alt.Chart(cv_result_df.T).mark_point(clip=True).encode(
    x = alt.X('mean_test_score').scale(domain=(0.58, 0.7)),
    y=alt.Y(alt.repeat("row"), type='quantitative')
).properties(
    width=900
).repeat(
    row=cv_result_df.T.columns.to_list()[1:-1]
)

fig_hyperparam
# Out:
# alt.RepeatChart(...)

# %%
import pickle

if TUNING:

    # Save the entire pipeline model to a file using pickle
    with open('model/xgboost_opt.pkl', 'wb') as file:
        pickle.dump(random_search.best_estimator_.named_steps['xgbregressor'], file)

    # # Load the entire pipeline model from a file using pickle
    # with open('model/xgboost_opt.pkl', 'rb') as file:
    #     xgboost_test = pickle.load(file)

# %%
if TUNING:
    xgboost_opt = make_pipeline(random_search.best_estimator_)
else:
    with open('model/xgboost_opt.pkl', 'rb') as file:
        xgboost_opt = pickle.load(file)   
    xgboost_opt = make_pipeline(preprocessor_with_scaler, xgboost_opt)
                            
results_dict["xgboost optimized"] = mean_std_cross_val_scores(
    xgboost_opt, X_train, y_train, return_train_score=True
)
pd.DataFrame(results_dict).T
# Out:
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [2, 7, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 5, 7, 13, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/conda/envs/machine-learning/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:228: UserWarning: Found unknown categories in columns [3, 7, 14] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                              fit_time         score_time         test_score  \
# linear regression   1.126 (+/- 0.088)  0.106 (+/- 0.024)  0.436 (+/- 0.030)
# ridge               0.743 (+/- 0.024)  0.085 (+/- 0.004)  0.437 (+/- 0.030)
# xgboost             1.230 (+/- 0.009)  0.143 (+/- 0.007)  0.585 (+/- 0.052)
# xgboost optimized  19.824 (+/- 0.691)  3.485 (+/- 0.271)  0.664 (+/- 0.055)
#
#                          train_score
# linear regression  0.443 (+/- 0.007)
# ridge              0.443 (+/- 0.007)
# xgboost            0.680 (+/- 0.008)
# xgboost optimized  0.954 (+/- 0.003)

# %% [markdown]
# A more interpretable metric:

# %%
from sklearn.metrics import mean_absolute_percentage_error
# xgboost_opt.fit(X_train, y_train)
print(f'{mean_absolute_percentage_error(y_train["price"], xgboost_opt.predict(X_train)):.3f}')

prediction = y_train.copy()
prediction['pred'] = xgboost_opt.predict(X_train)
prediction['residual'] = prediction['price'] - prediction['pred']
prediction['perc_error'] = prediction['residual'] / prediction['price']

# alt.Chart(prediction).mark_point().encode(
#     x=alt.X('price'),
#     y=alt.Y('perc_error')
# )
prediction.sort_values('perc_error').head(20)
# Out:
# 0.064
#        price           pred       residual  perc_error
# 50556  10452   50474.984375  -40022.984375   -3.829218
# 22528   2322   11154.339844   -8832.339844   -3.803764
# 60362    119     543.258362    -424.258362   -3.565196
# 649      407    1802.946533   -1395.946533   -3.429844
# 62023  26433   69235.328125  -42802.328125   -1.619276
# 6820   38208   99278.929688  -61070.929688   -1.598381
# 27242  52662  131113.328125  -78451.328125   -1.489714
# 59614  73707  181780.578125 -108073.578125   -1.466259
# 7281   15283   34957.632812  -19674.632812   -1.287354
# 20988   7371   16604.248047   -9233.248047   -1.252645
# 42728   3317    7305.977539   -3988.977539   -1.202586
# 60359    151     329.867401    -178.867401   -1.184552
# 26821  55915  122036.937500  -66121.937500   -1.182544
# 10972  28062   61000.867188  -32938.867188   -1.173789
# 8934   15693   33816.503906  -18123.503906   -1.154878
# 64107   5573   11897.275391   -6324.275391   -1.134806
# 36855  73746  156544.687500  -82798.687500   -1.122755
# 10700  54690  115534.429688  -60844.429688   -1.112533
# 3568   33713   71215.296875  -37502.296875   -1.112399
# 59601  86415  181780.578125  -95365.578125   -1.103577

# %%
alt.Chart(prediction,
          title='Histogram of predicted price').mark_bar().encode(
    alt.X('pred:Q').bin(maxbins=60),
    y='count()'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Prediction on Test Set

# %%
# Fit the optimized model
xgboost_opt.fit(X_train, y_train)

xgboost_opt.score(X_test, y_test)
# Out:
# 0.676354307761087

# %%
xgboost_opt
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('columntransformer',
#                                   ColumnTransformer(transformers=[('pipeline-1',
#                                                                    Pipeline(steps=[('onehotencoder',
#                                                                                     OneHotEncoder(drop='if_binary',
#                                                                                                   handle_unknown='ignore'))]),
#                                                                    ['model',
#                                                                     'movement',
#                                                                     'case_material',
#                                                                     'bracelet_material',
#                                                                     'year_is_approximated',
#                                                                     'condition',
#                                                                     'scope_of_delivery',
#                                                                     'country',
#                                                                     'availability',
#                                                                     'bezel_mate...
#                                                feature_types=None, gamma=None,
#                                                grow_policy=None,
#                                                importance_type=None,
#                                                interaction_constraints=None,
#                                                lambda=96.5,
#                                                learning_rate=0.34099999999999997,
#                                                max_bin=None,
#                                                max_cat_threshold=None,
#                                                max_cat_to_onehot=None,
#                                                max_delta_step=None,
#                                                max_depth=19, max_leaves=500,
#                                                min_child_weight=None,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=1300, n_jobs=-1, ...))]))])

# %%
test_pred = y_test.copy()
test_pred['prediction'] = xgboost_opt.predict(X_test)
test_pred['residual'] = test_pred['price'] - test_pred['prediction']
test_pred.head()
# Out:
#        price    prediction      residual
# 26441  87745  74007.976562  13737.023438
# 46268  16634  18416.087891  -1782.087891
# 18088  14459  16442.650391  -1983.650391
# 33935  60293  67959.023438  -7666.023438
# 45197  34911  35702.300781   -791.300781

# %%
prediction_plot = alt.Chart(test_pred, title='Actual Listing Price and Prediction').mark_point().encode(
    alt.X('price').title('Actual Price'),
    alt.Y('prediction').title('Predicted Price')
)

min_price = min(test_pred['price'].min(), test_pred['prediction'].min())
max_price = max(test_pred['price'].max(), test_pred['prediction'].max())

# Create a DataFrame for the 45-degree line
line_data = pd.DataFrame({
    'price': [min_price, max_price],
    'prediction': [min_price, max_price]
})

# Create the 45-degree line chart
line_chart = alt.Chart(line_data).mark_line(color='red').encode(
    x='price',
    y='prediction'
)

prediction_plot + line_chart
# Out:
# alt.LayerChart(...)

# %%
fig_pred = alt.Chart(test_pred).mark_point(clip=True).encode(
    x=alt.X('price').scale(domain=[0, 120000]),
    y=alt.Y('prediction').scale(domain=[0, 120000])
)
line_chart = alt.Chart(line_data).mark_line(color='red', clip=True).encode(
    x=alt.X('price').scale(domain=[0, 120000]),
    y=alt.Y('prediction').scale(domain=[0, 120000])
)

fig_pred 
(fig_pred + line_chart).configure_mark(
    opacity=0.3
)
# Out:
# alt.LayerChart(...)
